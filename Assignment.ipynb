# %%
print("i am rob")
# Out:
# i am rob

# %% [markdown]
# **my first program**

# %% [markdown]
# **variable declaration**

# %%
a=10
b=20
sum=a+b
print(sum)
# Out:
# 30

# %% [markdown]
# **subtraction**

# %%
a=10
b=5
sub=a-b
print(sub)
# Out:
# 5

# %%
a=10
b=5
c=2
sub =a-b-c
print(sub)
# Out:
# 3

# %% [markdown]
# **product of two numbers**

# %%
a=5
b=5
mul=a*b
print(mul)
# Out:
# 25

# %% [markdown]
# **division**

# %%
a=10
b=2
div=a/b
rem=a%b
print(div)
print(rem)
# Out:
# 5.0
# 0

# %% [markdown]
# **squaring of numbers**

# %%
a=6
sqr=a*a
print(sqr)
# Out:
# 36

# %% [markdown]
# **square root**

# %%
import math
a=9
math.sqrt(a)
# Out:
# 3.0

# %% [markdown]
# **mathematical operation**

# %%
a=4
b=8
c=6
ans=(a+b)*c
print(ans)
# Out:
# 72
