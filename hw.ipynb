# %%
a=10
b=20
sum=a+b
print(sum)
# Out:
# 30

# %% [markdown]
# **tuple**

# %%
tuple1=("hubli","belgaum","hubli")
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
a=tuple1.index('hubli')
print(a)
# Out:
# hubli
# belgaum
# hubli
# 0

# %% [markdown]
# Python program to check if the input number is odd or even. A number is even if division by 2 gives a remainder of 0.
#  If the remainder is 1, it is an odd number.

# %%
num = int(input("Enter a number: "))
if (num % 2) == 0:
   print("{0} is Even".format(num))
else:
   print("{0} is Odd".format(num))
# Out:
# Enter a number: 45
# 45 is Odd

# %%
# Python program to swap two variables

x = 5
y = 10


temp = x
x = y
y = temp

print('The value of x after swapping: {}'.format(x))
print('The value of y after swapping: {}'.format(y))
# Out:
# The value of x after swapping: 10
# The value of y after swapping: 5

# %%
def maximum(a, b):

    if a >= b:
        return a
    else:
        return b

# Driver code
a = 2
b = 4
print(maximum(a, b))
# Out:
# 4

# %%
if a>b:
  print("the value of a is greater than b")

else:
  print('hello')
# Out:
# hello

# %%
tuple1=("sports", "culture", "teacher")
print(type(tuple1))
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
tuple2=tuple1+tuple1
print(tuple2)

a=tuple2.index('teacher')
print(a)

b=tuple2.count('teacher')
print(b)
# Out:
# <class 'tuple'>
# sports
# culture
# teacher
# ('sports', 'culture', 'teacher', 'sports', 'culture', 'teacher')
# 2
# 2

# %%
Dict1={"Name": "ram",
     "Age":"16",
     "Gender": "male","Year":"2009","Year":"2003"}
print(Dict1)
# Out:
# {'Name': 'ram', 'Age': '16', 'Gender': 'male', 'Year': '2003'}

# %%
set1={"colur","vegetable", "fruit"}
print(set1)
set1.add('orange')
print(set1)
set2={"umpire","batsman","wicket"}
set1.update(set2)
print(set1)
# Out:
# {'colur', 'fruit', 'vegetable'}
# {'colur', 'orange', 'fruit', 'vegetable'}
# {'vegetable', 'fruit', 'colur', 'umpire', 'orange', 'wicket', 'batsman'}

# %%
print(2 & 8)
print(0xC ^ 0xD)
print(0XA | 9)
print(3*9)
print(4+6)
print(3-2)
print(10>>2)
print(8<<2)
# Out:
# 0
# 1
# 11
# 27
# 10
# 1
# 2
# 32
